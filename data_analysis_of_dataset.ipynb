# %% [markdown]
# ### Data Loading

# %%
import pandas as pd

df = pd.read_csv("Sales Forecasting Dataset.csv")

# %% [markdown]
# # 1. HEAD used to display the first few rows of a dataset.

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %% [markdown]
# # 2. All available columns in the dataset.

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='str')

# %% [markdown]
# # 3. DESCRIBE shows statistical summary(numerical columns) of dataset.

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %% [markdown]
# # I4. nclude categorical column statistics as well.

# %%
df.describe(include='object')
# Out:
# C:\Users\Priya\AppData\Local\Temp\ipykernel_2444\87514550.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include='object')
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# count             9800        9800        9800            9800        9800
# unique            4922        1230        1326               4         793
# top     CA-2018-100111  05/09/2017  26/09/2018  Standard Class    WB-21850
# freq                14          38          34            5859          35
#
# ...

# %% [markdown]
# # 5. Used to find missing values.

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %% [markdown]
# ### DATA CLEANING

# %% [markdown]
# # 6. Handling missing values[Mean → if data is normal Median → if data is skewed].

# %%
# For numerical data
df['Postal Code'] = df['Postal Code'].fillna(df['Postal Code'].mean())

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %% [markdown]
# # 7. Check duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Sales Trend

# %% [markdown]
# # 8. Sales in every month

# %%
import matplotlib.pyplot as plt

#  Convert to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True, errors='coerce')

# Create Month Name column
df['Month'] = df['Order Date'].dt.month_name()

# Remove NaN rows (important)
df = df.dropna(subset=['Month'])

# Group by Month (simple way first)
monthly_sales = df.groupby('Month')['Sales'].sum()

# Fix correct order using reindex
month_order = [
    'January','February','March','April','May','June',
    'July','August','September','October','November','December'
]

monthly_sales = monthly_sales.reindex(month_order)

# Step 6: Print result
print(monthly_sales)

# Step 7: Plot
monthly_sales.plot()
plt.title("Monthly Sales Trend")
plt.xticks(rotation=45)
plt.show()
# Out:
# Month
# January       94291.6296
# February      59371.1154
# March        197573.5872
# April        136283.0006
# May          154086.7237
# June         145837.5233
# July         145535.6890
# August       157315.9270
# September    300103.4117
# October      199496.2947
# November     350161.7110
# December     321480.1695
# Name: Sales, dtype: float64

# %% [markdown]
# # 9. Category wise sales

# %%
df.groupby('Category')['Sales'].sum()
# Out:
# Category
# Furniture          728658.5757
# Office Supplies    705422.3340
# Technology         827455.8730
# Name: Sales, dtype: float64

# %% [markdown]
# # 10. Region wise sales

# %%
df.groupby('Region')['Sales'].sum()
# Out:
# Region
# Central    492646.9132
# East       669518.7260
# South      389151.4590
# West       710219.6845
# Name: Sales, dtype: float64

# %% [markdown]
# # 11. Top Products

# %%
df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %% [markdown]
# ### Import dataset in postgresql

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import psycopg2
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# Step 1: Define variables
dbname = "customer_analysis"
user = "postgres"
password = "priya@1009"
host = "localhost"
port = "5432"

# Step 2: Encode password (IMPORTANT because of @)
encoded_password = quote_plus(password)

# Step 3: Create engine
engine = create_engine(
    f"postgresql+psycopg2://{user}:{encoded_password}@{host}:{port}/{dbname}"
)

# Step 4: Load data
table_name = "customer"
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"✅ Data loaded into table '{table_name}' in database '{dbname}'")
# Out:
# ✅ Data loaded into table 'customer' in database 'customer_analysis'
